# %%
import cv2
import numpy as np
import os
from keras.preprocessing.image import ImageDataGenerator
from keras import backend as K
import keras
from keras.models import Sequential, Model,load_model
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping,ModelCheckpoint
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D,MaxPool2D
from keras.preprocessing import image
from keras.initializers import glorot_uniform

# %%
K._get_available_gpus()
# Out:
# ['/device:GPU:0', '/device:GPU:1']

# %%
input_size = (224, 224)
dataset_directory = 'data/training_set'

images = []
labels = []

for class_name in os.listdir(dataset_directory):
    class_directory = os.path.join(dataset_directory, class_name)
    
    if os.path.isdir(class_directory):
        for image_filename in os.listdir(class_directory):
            image_path = os.path.join(class_directory, image_filename)
            
            image = cv2.imread(image_path)
            
            if image is not None:
                image = cv2.resize(image, input_size)
                images.append(image)
                labels.append(class_name)

xtrain = np.array(images)
ytrain = np.array(labels)

print("Shape of images array:", xtrain.shape)
print("Shape of labels array:", ytrain.shape)
# Out:
# Shape of images array: (8005, 224, 224, 3)
# Shape of labels array: (8005,)

# %%
input_size = (224, 224)
dataset_directory = 'data/test_set'

images = []
labels = []

for class_name in os.listdir(dataset_directory):
    class_directory = os.path.join(dataset_directory, class_name)
    
    if os.path.isdir(class_directory):
        for image_filename in os.listdir(class_directory):
            image_path = os.path.join(class_directory, image_filename)
            
            image = cv2.imread(image_path)
            
            if image is not None:
                image = cv2.resize(image, input_size)
                images.append(image)
                labels.append(class_name)

xtest = np.array(images)
ytest = np.array(labels)

print("Shape of images array:", xtest.shape)
print("Shape of labels array:", ytest.shape)
# Out:
# Shape of images array: (2023, 224, 224, 3)
# Shape of labels array: (2023,)

# %%
import matplotlib.pyplot as plt
plt.imshow(xtrain[100])

# %%
plt.imshow(xtrain[4000])

# %%
plt.imshow(xtest[100])

# %%
def identity_block(X, f, filters, stage, block):
   
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    F1, F2, F3 = filters

    X_shortcut = X
   
    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2a', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    X = Add()([X, X_shortcut])# SKIP Connection
    X = Activation('relu')(X)

    return X

# %%
def convolutional_block(X, f, filters, stage, block, s=2):
   
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    F1, F2, F3 = filters

    X_shortcut = X

    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(s, s), padding='valid', name=conv_name_base + '2a', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    X_shortcut = Conv2D(filters=F3, kernel_size=(1, 1), strides=(s, s), padding='valid', name=conv_name_base + '1', kernel_initializer=glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis=3, name=bn_name_base + '1')(X_shortcut)

    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

# %%
def ResNet50(input_shape=(224, 224, 3)):

    X_input = Input(input_shape)

    X = ZeroPadding2D((3, 3))(X_input)

    X = Conv2D(64, (7, 7), strides=(2, 2), name='conv1', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name='bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    X = convolutional_block(X, f=3, filters=[64, 64, 256], stage=2, block='a', s=1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')


    X = convolutional_block(X, f=3, filters=[128, 128, 512], stage=3, block='a', s=2)
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='d')

    X = convolutional_block(X, f=3, filters=[256, 256, 1024], stage=4, block='a', s=2)
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')

    X = X = convolutional_block(X, f=3, filters=[512, 512, 2048], stage=5, block='a', s=2)
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')

    X = AveragePooling2D(pool_size=(2, 2), padding='same')(X)
    
    model = Model(inputs=X_input, outputs=X, name='ResNet50')

    return model

# %%
base_model = ResNet50(input_shape=(224, 224, 3))

# %%
headModel = base_model.output
headModel = Flatten()(headModel)
headModel=Dense(256, activation='relu', name='fc1',kernel_initializer=glorot_uniform(seed=0))(headModel)
headModel=Dense(128, activation='relu', name='fc2',kernel_initializer=glorot_uniform(seed=0))(headModel)
headModel = Dense( 1,activation='sigmoid', name='fc3',kernel_initializer=glorot_uniform(seed=0))(headModel)

# %%
model = Model(inputs=base_model.input, outputs=headModel)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0          ['input_1[0][0]']
#
#  conv1 (Conv2D)                 (None, 112, 112, 64  9472        ['zero_padding2d[0][0]']
#                                 )
#
#  bn_conv1 (BatchNormalization)  (None, 112, 112, 64  256         ['conv1[0][0]']
#                                 )
#
#  activation (Activation)        (None, 112, 112, 64  0           ['bn_conv1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 55, 55, 64)   0           ['activation[0][0]']
#
#  res2a_branch2a (Conv2D)        (None, 55, 55, 64)   4160        ['max_pooling2d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 55, 55, 64)  256         ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 55, 55, 64)   0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv2D)        (None, 55, 55, 64)   36928       ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 55, 55, 64)  256         ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 55, 55, 64)   0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv2D)        (None, 55, 55, 256)  16640       ['activation_2[0][0]']
#
#  res2a_branch1 (Conv2D)         (None, 55, 55, 256)  16640       ['max_pooling2d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 55, 55, 256)  1024       ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 55, 55, 256)  1024       ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 55, 55, 256)  0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 55, 55, 256)  0           ['add[0][0]']
#
#  res2b_branch2a (Conv2D)        (None, 55, 55, 64)   16448       ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 55, 55, 64)  256         ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 55, 55, 64)   0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv2D)        (None, 55, 55, 64)   36928       ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 55, 55, 64)  256         ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 55, 55, 64)   0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv2D)        (None, 55, 55, 256)  16640       ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 55, 55, 256)  1024       ['res2b_branch2c[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 55, 55, 256)  0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 55, 55, 256)  0           ['add_1[0][0]']
#
#  res2c_branch2a (Conv2D)        (None, 55, 55, 64)   16448       ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 55, 55, 64)  256         ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 55, 55, 64)   0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv2D)        (None, 55, 55, 64)   36928       ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 55, 55, 64)  256         ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 55, 55, 64)   0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv2D)        (None, 55, 55, 256)  16640       ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 55, 55, 256)  1024       ['res2c_branch2c[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 55, 55, 256)  0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 55, 55, 256)  0           ['add_2[0][0]']
#
#  res3a_branch2a (Conv2D)        (None, 28, 28, 128)  32896       ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 28, 28, 128)  512        ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 28, 28, 128)  0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv2D)        (None, 28, 28, 128)  147584      ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 28, 28, 128)  512        ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 28, 28, 128)  0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv2D)        (None, 28, 28, 512)  66048       ['activation_11[0][0]']
#
#  res3a_branch1 (Conv2D)         (None, 28, 28, 512)  131584      ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 28, 28, 512)  2048       ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 28, 28, 512)  2048       ['res3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 28, 28, 512)  0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 28, 28, 512)  0           ['add_3[0][0]']
#
#  res3b_branch2a (Conv2D)        (None, 28, 28, 128)  65664       ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 28, 28, 128)  512        ['res3b_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 28, 28, 128)  0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv2D)        (None, 28, 28, 128)  147584      ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 28, 28, 128)  512        ['res3b_branch2b[0][0]']
#  ion)
#
#  activation_14 (Activation)     (None, 28, 28, 128)  0           ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv2D)        (None, 28, 28, 512)  66048       ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormalizat  (None, 28, 28, 512)  2048       ['res3b_branch2c[0][0]']
#  ion)
#
#  add_4 (Add)                    (None, 28, 28, 512)  0           ['bn3b_branch2c[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 28, 28, 512)  0           ['add_4[0][0]']
#
#  res3c_branch2a (Conv2D)        (None, 28, 28, 128)  65664       ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 28, 28, 128)  512        ['res3c_branch2a[0][0]']
#  ion)
#
#  activation_16 (Activation)     (None, 28, 28, 128)  0           ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv2D)        (None, 28, 28, 128)  147584      ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 28, 28, 128)  512        ['res3c_branch2b[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 28, 28, 128)  0           ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv2D)        (None, 28, 28, 512)  66048       ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormalizat  (None, 28, 28, 512)  2048       ['res3c_branch2c[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 28, 28, 512)  0           ['bn3c_branch2c[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 28, 28, 512)  0           ['add_5[0][0]']
#
#  res3d_branch2a (Conv2D)        (None, 28, 28, 128)  65664       ['activation_18[0][0]']
#
#  bn3d_branch2a (BatchNormalizat  (None, 28, 28, 128)  512        ['res3d_branch2a[0][0]']
#  ion)
#
#  activation_19 (Activation)     (None, 28, 28, 128)  0           ['bn3d_branch2a[0][0]']
#
#  res3d_branch2b (Conv2D)        (None, 28, 28, 128)  147584      ['activation_19[0][0]']
#
#  bn3d_branch2b (BatchNormalizat  (None, 28, 28, 128)  512        ['res3d_branch2b[0][0]']
#  ion)
#
#  activation_20 (Activation)     (None, 28, 28, 128)  0           ['bn3d_branch2b[0][0]']
#
#  res3d_branch2c (Conv2D)        (None, 28, 28, 512)  66048       ['activation_20[0][0]']
#
#  bn3d_branch2c (BatchNormalizat  (None, 28, 28, 512)  2048       ['res3d_branch2c[0][0]']
#  ion)
#
#  add_6 (Add)                    (None, 28, 28, 512)  0           ['bn3d_branch2c[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_21 (Activation)     (None, 28, 28, 512)  0           ['add_6[0][0]']
#
#  res4a_branch2a (Conv2D)        (None, 14, 14, 256)  131328      ['activation_21[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4a_branch2a[0][0]']
#  ion)
#
#  activation_22 (Activation)     (None, 14, 14, 256)  0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_22[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4a_branch2b[0][0]']
#  ion)
#
#  activation_23 (Activation)     (None, 14, 14, 256)  0           ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_23[0][0]']
#                                 )
#
#  res4a_branch1 (Conv2D)         (None, 14, 14, 1024  525312      ['activation_21[0][0]']
#                                 )
#
#  bn4a_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4a_branch2c[0][0]']
#  ion)                           )
#
#  bn4a_branch1 (BatchNormalizati  (None, 14, 14, 1024  4096       ['res4a_branch1[0][0]']
#  on)                            )
#
#  add_7 (Add)                    (None, 14, 14, 1024  0           ['bn4a_branch2c[0][0]',
#                                 )                                 'bn4a_branch1[0][0]']
#
#  activation_24 (Activation)     (None, 14, 14, 1024  0           ['add_7[0][0]']
#                                 )
#
#  res4b_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_24[0][0]']
#
#  bn4b_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4b_branch2a[0][0]']
#  ion)
#
#  activation_25 (Activation)     (None, 14, 14, 256)  0           ['bn4b_branch2a[0][0]']
#
#  res4b_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_25[0][0]']
#
#  bn4b_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4b_branch2b[0][0]']
#  ion)
#
#  activation_26 (Activation)     (None, 14, 14, 256)  0           ['bn4b_branch2b[0][0]']
#
#  res4b_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_26[0][0]']
#                                 )
#
#  bn4b_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4b_branch2c[0][0]']
#  ion)                           )
#
#  add_8 (Add)                    (None, 14, 14, 1024  0           ['bn4b_branch2c[0][0]',
#                                 )                                 'activation_24[0][0]']
#
#  activation_27 (Activation)     (None, 14, 14, 1024  0           ['add_8[0][0]']
#                                 )
#
#  res4c_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_27[0][0]']
#
#  bn4c_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4c_branch2a[0][0]']
#  ion)
#
#  activation_28 (Activation)     (None, 14, 14, 256)  0           ['bn4c_branch2a[0][0]']
#
#  res4c_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_28[0][0]']
#
#  bn4c_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4c_branch2b[0][0]']
#  ion)
#
#  activation_29 (Activation)     (None, 14, 14, 256)  0           ['bn4c_branch2b[0][0]']
#
#  res4c_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_29[0][0]']
#                                 )
#
#  bn4c_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4c_branch2c[0][0]']
#  ion)                           )
#
#  add_9 (Add)                    (None, 14, 14, 1024  0           ['bn4c_branch2c[0][0]',
#                                 )                                 'activation_27[0][0]']
#
#  activation_30 (Activation)     (None, 14, 14, 1024  0           ['add_9[0][0]']
#                                 )
#
#  res4d_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_30[0][0]']
#
#  bn4d_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4d_branch2a[0][0]']
#  ion)
#
#  activation_31 (Activation)     (None, 14, 14, 256)  0           ['bn4d_branch2a[0][0]']
#
#  res4d_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_31[0][0]']
#
#  bn4d_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4d_branch2b[0][0]']
#  ion)
#
#  activation_32 (Activation)     (None, 14, 14, 256)  0           ['bn4d_branch2b[0][0]']
#
#  res4d_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_32[0][0]']
#                                 )
#
#  bn4d_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4d_branch2c[0][0]']
#  ion)                           )
#
#  add_10 (Add)                   (None, 14, 14, 1024  0           ['bn4d_branch2c[0][0]',
#                                 )                                 'activation_30[0][0]']
#
#  activation_33 (Activation)     (None, 14, 14, 1024  0           ['add_10[0][0]']
#                                 )
#
#  res4e_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_33[0][0]']
#
#  bn4e_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4e_branch2a[0][0]']
#  ion)
#
#  activation_34 (Activation)     (None, 14, 14, 256)  0           ['bn4e_branch2a[0][0]']
#
#  res4e_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_34[0][0]']
#
#  bn4e_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4e_branch2b[0][0]']
#  ion)
#
#  activation_35 (Activation)     (None, 14, 14, 256)  0           ['bn4e_branch2b[0][0]']
#
#  res4e_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_35[0][0]']
#                                 )
#
#  bn4e_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4e_branch2c[0][0]']
#  ion)                           )
#
#  add_11 (Add)                   (None, 14, 14, 1024  0           ['bn4e_branch2c[0][0]',
#                                 )                                 'activation_33[0][0]']
#
#  activation_36 (Activation)     (None, 14, 14, 1024  0           ['add_11[0][0]']
#                                 )
#
#  res4f_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_36[0][0]']
#
#  bn4f_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4f_branch2a[0][0]']
#  ion)
#
#  activation_37 (Activation)     (None, 14, 14, 256)  0           ['bn4f_branch2a[0][0]']
#
#  res4f_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_37[0][0]']
#
#  bn4f_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4f_branch2b[0][0]']
#  ion)
#
#  activation_38 (Activation)     (None, 14, 14, 256)  0           ['bn4f_branch2b[0][0]']
#
#  res4f_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_38[0][0]']
#                                 )
#
#  bn4f_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4f_branch2c[0][0]']
#  ion)                           )
#
#  add_12 (Add)                   (None, 14, 14, 1024  0           ['bn4f_branch2c[0][0]',
#                                 )                                 'activation_36[0][0]']
#
#  activation_39 (Activation)     (None, 14, 14, 1024  0           ['add_12[0][0]']
#                                 )
#
#  res5a_branch2a (Conv2D)        (None, 7, 7, 512)    524800      ['activation_39[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5a_branch2a[0][0]']
#  ion)
#
#  activation_40 (Activation)     (None, 7, 7, 512)    0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv2D)        (None, 7, 7, 512)    2359808     ['activation_40[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5a_branch2b[0][0]']
#  ion)
#
#  activation_41 (Activation)     (None, 7, 7, 512)    0           ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv2D)        (None, 7, 7, 2048)   1050624     ['activation_41[0][0]']
#
#  res5a_branch1 (Conv2D)         (None, 7, 7, 2048)   2099200     ['activation_39[0][0]']
#
#  bn5a_branch2c (BatchNormalizat  (None, 7, 7, 2048)  8192        ['res5a_branch2c[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 7, 7, 2048)  8192        ['res5a_branch1[0][0]']
#  on)
#
#  add_13 (Add)                   (None, 7, 7, 2048)   0           ['bn5a_branch2c[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_42 (Activation)     (None, 7, 7, 2048)   0           ['add_13[0][0]']
#
#  res5b_branch2a (Conv2D)        (None, 7, 7, 512)    1049088     ['activation_42[0][0]']
#
#  bn5b_branch2a (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5b_branch2a[0][0]']
#  ion)
#
#  activation_43 (Activation)     (None, 7, 7, 512)    0           ['bn5b_branch2a[0][0]']
#
#  res5b_branch2b (Conv2D)        (None, 7, 7, 512)    2359808     ['activation_43[0][0]']
#
#  bn5b_branch2b (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5b_branch2b[0][0]']
#  ion)
#
#  activation_44 (Activation)     (None, 7, 7, 512)    0           ['bn5b_branch2b[0][0]']
#
#  res5b_branch2c (Conv2D)        (None, 7, 7, 2048)   1050624     ['activation_44[0][0]']
#
#  bn5b_branch2c (BatchNormalizat  (None, 7, 7, 2048)  8192        ['res5b_branch2c[0][0]']
#  ion)
#
#  add_14 (Add)                   (None, 7, 7, 2048)   0           ['bn5b_branch2c[0][0]',
#                                                                   'activation_42[0][0]']
#
#  activation_45 (Activation)     (None, 7, 7, 2048)   0           ['add_14[0][0]']
#
#  res5c_branch2a (Conv2D)        (None, 7, 7, 512)    1049088     ['activation_45[0][0]']
#
#  bn5c_branch2a (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5c_branch2a[0][0]']
#  ion)
#
#  activation_46 (Activation)     (None, 7, 7, 512)    0           ['bn5c_branch2a[0][0]']
#
#  res5c_branch2b (Conv2D)        (None, 7, 7, 512)    2359808     ['activation_46[0][0]']
#
#  bn5c_branch2b (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5c_branch2b[0][0]']
#  ion)
#
#  activation_47 (Activation)     (None, 7, 7, 512)    0           ['bn5c_branch2b[0][0]']
#
#  res5c_branch2c (Conv2D)        (None, 7, 7, 2048)   1050624     ['activation_47[0][0]']
#
#  bn5c_branch2c (BatchNormalizat  (None, 7, 7, 2048)  8192        ['res5c_branch2c[0][0]']
#  ion)
#
#  add_15 (Add)                   (None, 7, 7, 2048)   0           ['bn5c_branch2c[0][0]',
#                                                                   'activation_45[0][0]']
#
#  activation_48 (Activation)     (None, 7, 7, 2048)   0           ['add_15[0][0]']
#
#  average_pooling2d (AveragePool  (None, 4, 4, 2048)  0           ['activation_48[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 32768)        0           ['average_pooling2d[0][0]']
#
#  fc1 (Dense)                    (None, 256)          8388864     ['flatten[0][0]']
#
#  fc2 (Dense)                    (None, 128)          32896       ['fc1[0][0]']
#
#  fc3 (Dense)                    (None, 1)            129         ['fc2[0][0]']
#
# ==================================================================================================
# Total params: 32,009,601
# Trainable params: 31,956,481
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
base_model.load_weights("resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5")

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
for layer in model.layers:
    print(f"{layer}: {layer.trainable}\n")
# Out:
# <keras.engine.input_layer.InputLayer object at 0x000001AFDA1F0520>: False
#
# <keras.layers.reshaping.zero_padding2d.ZeroPadding2D object at 0x000001AFDA30C8E0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA30C850>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AF46D34130>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA3A3310>: False
#
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x000001AFDA3F0A60>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA655490>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA655790>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA655730>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA662A90>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA669CD0>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA669A90>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA66ECA0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA67BB20>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA67B7C0>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA66E100>: False
#
# <keras.layers.merging.add.Add object at 0x000001AFDA6889D0>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA6867F0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA692D30>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA692F70>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA692FD0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA698640>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA69DEB0>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA69DC70>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA6A5640>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA6ABD00>: False
#
# <keras.layers.merging.add.Add object at 0x000001AFDA6B7520>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA6B1520>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA6BED30>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA6BEF70>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA6BEFD0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA6C4D90>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA6CAEB0>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA6D1490>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA6CA460>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA6CA730>: False
#
# <keras.layers.merging.add.Add object at 0x000001AFDA69D880>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA676A30>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA67B4F0>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA6624C0>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA6B76A0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA6D9BB0>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA688F40>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA669DF0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA6D0B50>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA6DEDF0>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA6DEBB0>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA6E11F0>: False
#
# <keras.layers.merging.add.Add object at 0x000001AFDA6E14F0>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA6F22E0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA6E5880>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA6F5910>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA700A60>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA6F5A60>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA6F2DC0>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA70CA00>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA709DF0>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA6F5160>: False
#
# <keras.layers.merging.add.Add object at 0x000001AFDA6F5AF0>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA71A9D0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA71F490>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA726940>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA7268E0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA72D6A0>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA71A3A0>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA71FFA0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA736DF0>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA742BB0>: False
#
# <keras.layers.merging.add.Add object at 0x000001AFDA72D070>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA748310>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA74C700>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA754940>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA75BA90>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA75B610>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA74C070>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA726190>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA71F820>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA7540A0>: False
#
# <keras.layers.merging.add.Add object at 0x000001AFDA70CF10>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA6DE700>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA6D2E20>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA6D9880>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA676460>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA7605E0>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA6E1EB0>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA75E580>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA766EB0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA76A700>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA769BB0>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA76A340>: False
#
# <keras.layers.merging.add.Add object at 0x000001AFDA766F10>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA777250>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA772520>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA77D8E0>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA788A30>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA77DB80>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA76C670>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDB8939D0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDB890E50>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA77D070>: False
#
# <keras.layers.merging.add.Add object at 0x000001AFDB89A880>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA76C2E0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDB8A7550>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDB8AD910>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDB8B5A90>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDB8B5DF0>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDB8A0910>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDB8AD8B0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDB8BCE50>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDB8C9BB0>: False
#
# <keras.layers.merging.add.Add object at 0x000001AFDB8CE700>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDB8CE3A0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDB8BCA00>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDB8B5D60>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDB8A0FD0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA77DE80>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDB8BCAF0>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA769340>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA75E490>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDB8BC460>: False
#
# <keras.layers.merging.add.Add object at 0x000001AFDA709880>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA772C70>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDB8DC640>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDB8DE8E0>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDB8DE880>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDB8DF5E0>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA6E54C0>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDB8D2670>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDB8DC4C0>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AF56D0E370>: False
#
# <keras.layers.merging.add.Add object at 0x000001AF56D4B2E0>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AF56CCE3A0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDB8E8E20>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDB8DF7C0>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDB8FD820>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDB8FD520>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDB8F58E0>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDB8FDCD0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDB90D970>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDB8F5880>: False
#
# <keras.layers.merging.add.Add object at 0x000001AFDDA2C6A0>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDB8EF5E0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDB90D760>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDB90D640>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDDA25AC0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDDA3CD60>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDDA2CFD0>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDB90DB80>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDDA4AB80>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDDA5C760>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDDA3C910>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDDA54DF0>: False
#
# <keras.layers.merging.add.Add object at 0x000001AFDDA54850>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDDA5C700>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDDA33940>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDDA33910>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDDA4A6A0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDB90D580>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDDA3C520>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDB8EFFA0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDDA33F40>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDB8E5B50>: False
#
# <keras.layers.merging.add.Add object at 0x000001AFDB8E5A00>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDDA540D0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFDA766E20>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDB8E5A30>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDDA45DF0>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFE1C827F0>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFDA6E51C0>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDA788E20>: False
#
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001AFE1C89C70>: False
#
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001AFE1C92CA0>: False
#
# <keras.layers.merging.add.Add object at 0x000001AFDB8DFC70>: False
#
# <keras.layers.core.activation.Activation object at 0x000001AFDB8DC040>: False
#
# <keras.layers.pooling.average_pooling2d.AveragePooling2D object at 0x000001AFE1C8CD60>: False
#
# <keras.layers.reshaping.flatten.Flatten object at 0x000001AFDDA25220>: True
#
# <keras.layers.core.dense.Dense object at 0x000001AFDA372370>: True
#
# <keras.layers.core.dense.Dense object at 0x000001AFDA372CD0>: True
#
# <keras.layers.core.dense.Dense object at 0x000001AFEA0FB8B0>: True

# %%
opt = SGD(learning_rate=1e-3, momentum=0.9)
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])

# %%
es=EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=20)

# %%
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy')

# %%
ytrain
# Out:
# array(['cats', 'cats', 'cats', ..., 'dogs', 'dogs', 'dogs'], dtype='<U4')

# %%
ytest
# Out:
# array(['cats', 'cats', 'cats', ..., 'dogs', 'dogs', 'dogs'], dtype='<U4')

# %%
from sklearn.preprocessing import LabelBinarizer
l = LabelBinarizer()
ytrain = l.fit_transform(ytrain)
ytest = l.transform(ytest)

# %%
ytrain
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [1],
#        [1],
#        [1]])

# %%
ytest
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [1],
#        [1],
#        [1]])

# %%
H = model.fit(xtrain,ytrain,epochs=100,verbose=1,callbacks=[mc,es])
# Out:
# Epoch 1/100
# 251/251 [==============================] - ETA: 0s - loss: 0.0765 - accuracy: 0.9696WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 35s 113ms/step - loss: 0.0765 - accuracy: 0.9696
# Epoch 2/100
# 250/251 [============================>.] - ETA: 0s - loss: 0.0118 - accuracy: 0.9960WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 28s 111ms/step - loss: 0.0118 - accuracy: 0.9960
# Epoch 3/100
# 250/251 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.9998WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 28s 112ms/step - loss: 0.0025 - accuracy: 0.9998
# Epoch 4/100
# 250/251 [============================>.] - ETA: 0s - loss: 9.4077e-04 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 28s 111ms/step - loss: 9.4019e-04 - accuracy: 1.0000
# Epoch 5/100
# 250/251 [============================>.] - ETA: 0s - loss: 6.2668e-04 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 28s 112ms/step - loss: 6.2629e-04 - accuracy: 1.0000
# Epoch 6/100
# 250/251 [============================>.] - ETA: 0s - loss: 4.7455e-04 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 29s 115ms/step - loss: 4.7444e-04 - accuracy: 1.0000
# Epoch 7/100
# 250/251 [============================>.] - ETA: 0s - loss: 3.8648e-04 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 28s 113ms/step - loss: 3.8623e-04 - accuracy: 1.0000
# Epoch 8/100
# 250/251 [============================>.] - ETA: 0s - loss: 3.2632e-04 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 30s 121ms/step - loss: 3.2611e-04 - accuracy: 1.0000
# Epoch 9/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.8135e-04 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 29s 116ms/step - loss: 2.8219e-04 - accuracy: 1.0000
# Epoch 10/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.4696e-04 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 29s 116ms/step - loss: 2.4754e-04 - accuracy: 1.0000
# Epoch 11/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.2051e-04 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 30s 118ms/step - loss: 2.2038e-04 - accuracy: 1.0000
# Epoch 12/100
# 250/251 [============================>.] - ETA: 0s - loss: 1.9891e-04 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 30s 118ms/step - loss: 1.9879e-04 - accuracy: 1.0000
# Epoch 13/100
# 250/251 [============================>.] - ETA: 0s - loss: 1.8044e-04 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 30s 118ms/step - loss: 1.8044e-04 - accuracy: 1.0000
# Epoch 14/100
# 250/251 [============================>.] - ETA: 0s - loss: 1.6468e-04 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 30s 120ms/step - loss: 1.6489e-04 - accuracy: 1.0000
# Epoch 15/100
# 250/251 [============================>.] - ETA: 0s - loss: 1.5205e-04 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 30s 120ms/step - loss: 1.5199e-04 - accuracy: 1.0000
# Epoch 16/100
# 250/251 [============================>.] - ETA: 0s - loss: 1.4145e-04 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 30s 120ms/step - loss: 1.4140e-04 - accuracy: 1.0000
# Epoch 17/100
# 250/251 [============================>.] - ETA: 0s - loss: 1.3131e-04 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 30s 120ms/step - loss: 1.3123e-04 - accuracy: 1.0000
# Epoch 18/100
# 250/251 [============================>.] - ETA: 0s - loss: 1.2285e-04 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 30s 120ms/step - loss: 1.2279e-04 - accuracy: 1.0000
# Epoch 19/100
# 250/251 [============================>.] - ETA: 0s - loss: 1.1551e-04 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 30s 121ms/step - loss: 1.1544e-04 - accuracy: 1.0000
# Epoch 20/100
# 250/251 [============================>.] - ETA: 0s - loss: 1.0881e-04 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 30s 121ms/step - loss: 1.0874e-04 - accuracy: 1.0000
# Epoch 21/100
# 250/251 [============================>.] - ETA: 0s - loss: 1.0265e-04 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 30s 121ms/step - loss: 1.0258e-04 - accuracy: 1.0000
# Epoch 22/100
# 250/251 [============================>.] - ETA: 0s - loss: 9.7108e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 30s 121ms/step - loss: 9.7047e-05 - accuracy: 1.0000
# Epoch 23/100
# 250/251 [============================>.] - ETA: 0s - loss: 9.2021e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 123ms/step - loss: 9.2089e-05 - accuracy: 1.0000
# Epoch 24/100
# 250/251 [============================>.] - ETA: 0s - loss: 8.7597e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 32s 126ms/step - loss: 8.7573e-05 - accuracy: 1.0000
# Epoch 25/100
# 250/251 [============================>.] - ETA: 0s - loss: 8.3561e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 124ms/step - loss: 8.3509e-05 - accuracy: 1.0000
# Epoch 26/100
# 250/251 [============================>.] - ETA: 0s - loss: 7.9650e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 123ms/step - loss: 7.9768e-05 - accuracy: 1.0000
# Epoch 27/100
# 250/251 [============================>.] - ETA: 0s - loss: 7.6140e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 124ms/step - loss: 7.6224e-05 - accuracy: 1.0000
# Epoch 28/100
# 250/251 [============================>.] - ETA: 0s - loss: 7.3126e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 124ms/step - loss: 7.3086e-05 - accuracy: 1.0000
# Epoch 29/100
# 250/251 [============================>.] - ETA: 0s - loss: 7.0272e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 125ms/step - loss: 7.0230e-05 - accuracy: 1.0000
# Epoch 30/100
# 250/251 [============================>.] - ETA: 0s - loss: 6.7509e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 125ms/step - loss: 6.7484e-05 - accuracy: 1.0000
# Epoch 31/100
# 250/251 [============================>.] - ETA: 0s - loss: 6.5018e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 124ms/step - loss: 6.4988e-05 - accuracy: 1.0000
# Epoch 32/100
# 250/251 [============================>.] - ETA: 0s - loss: 6.2583e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 122ms/step - loss: 6.2596e-05 - accuracy: 1.0000
# Epoch 33/100
# 250/251 [============================>.] - ETA: 0s - loss: 6.0452e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 123ms/step - loss: 6.0447e-05 - accuracy: 1.0000
# Epoch 34/100
# 250/251 [============================>.] - ETA: 0s - loss: 5.8413e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 122ms/step - loss: 5.8376e-05 - accuracy: 1.0000
# Epoch 35/100
# 250/251 [============================>.] - ETA: 0s - loss: 5.6473e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 30s 120ms/step - loss: 5.6446e-05 - accuracy: 1.0000
# Epoch 36/100
# 250/251 [============================>.] - ETA: 0s - loss: 5.4698e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 123ms/step - loss: 5.4664e-05 - accuracy: 1.0000
# Epoch 37/100
# 250/251 [============================>.] - ETA: 0s - loss: 5.2986e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 123ms/step - loss: 5.2979e-05 - accuracy: 1.0000
# Epoch 38/100
# 250/251 [============================>.] - ETA: 0s - loss: 5.1337e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 123ms/step - loss: 5.1377e-05 - accuracy: 1.0000
# Epoch 39/100
# 250/251 [============================>.] - ETA: 0s - loss: 4.9878e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 124ms/step - loss: 4.9911e-05 - accuracy: 1.0000
# Epoch 40/100
# 250/251 [============================>.] - ETA: 0s - loss: 4.8525e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 124ms/step - loss: 4.8494e-05 - accuracy: 1.0000
# Epoch 41/100
# 250/251 [============================>.] - ETA: 0s - loss: 4.7123e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 124ms/step - loss: 4.7122e-05 - accuracy: 1.0000
# Epoch 42/100
# 250/251 [============================>.] - ETA: 0s - loss: 4.5823e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 124ms/step - loss: 4.5800e-05 - accuracy: 1.0000
# Epoch 43/100
# 250/251 [============================>.] - ETA: 0s - loss: 4.4633e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 125ms/step - loss: 4.4606e-05 - accuracy: 1.0000
# Epoch 44/100
# 250/251 [============================>.] - ETA: 0s - loss: 4.3496e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 125ms/step - loss: 4.3468e-05 - accuracy: 1.0000
# Epoch 45/100
# 250/251 [============================>.] - ETA: 0s - loss: 4.2283e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 32s 128ms/step - loss: 4.2351e-05 - accuracy: 1.0000
# Epoch 46/100
# 250/251 [============================>.] - ETA: 0s - loss: 4.1339e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 125ms/step - loss: 4.1313e-05 - accuracy: 1.0000
# Epoch 47/100
# 250/251 [============================>.] - ETA: 0s - loss: 4.0348e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 123ms/step - loss: 4.0323e-05 - accuracy: 1.0000
# Epoch 48/100
# 250/251 [============================>.] - ETA: 0s - loss: 3.9347e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 32s 127ms/step - loss: 3.9390e-05 - accuracy: 1.0000
# Epoch 49/100
# 250/251 [============================>.] - ETA: 0s - loss: 3.8466e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 123ms/step - loss: 3.8446e-05 - accuracy: 1.0000
# Epoch 50/100
# 250/251 [============================>.] - ETA: 0s - loss: 3.7603e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 123ms/step - loss: 3.7581e-05 - accuracy: 1.0000
# Epoch 51/100
# 250/251 [============================>.] - ETA: 0s - loss: 3.6781e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 123ms/step - loss: 3.6758e-05 - accuracy: 1.0000
# Epoch 52/100
# 250/251 [============================>.] - ETA: 0s - loss: 3.5993e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 32s 126ms/step - loss: 3.5971e-05 - accuracy: 1.0000
# Epoch 53/100
# 250/251 [============================>.] - ETA: 0s - loss: 3.5209e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 125ms/step - loss: 3.5187e-05 - accuracy: 1.0000
# Epoch 54/100
# 250/251 [============================>.] - ETA: 0s - loss: 3.4511e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 126ms/step - loss: 3.4491e-05 - accuracy: 1.0000
# Epoch 55/100
# 250/251 [============================>.] - ETA: 0s - loss: 3.3796e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 125ms/step - loss: 3.3778e-05 - accuracy: 1.0000
# Epoch 56/100
# 250/251 [============================>.] - ETA: 0s - loss: 3.3148e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 31s 124ms/step - loss: 3.3128e-05 - accuracy: 1.0000
# Epoch 57/100
# 250/251 [============================>.] - ETA: 0s - loss: 3.2470e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 32s 126ms/step - loss: 3.2459e-05 - accuracy: 1.0000
# Epoch 58/100
# 250/251 [============================>.] - ETA: 0s - loss: 3.1856e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 36s 142ms/step - loss: 3.1853e-05 - accuracy: 1.0000
# Epoch 59/100
# 250/251 [============================>.] - ETA: 0s - loss: 3.1225e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 38s 152ms/step - loss: 3.1221e-05 - accuracy: 1.0000
# Epoch 60/100
# 250/251 [============================>.] - ETA: 0s - loss: 3.0669e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 39s 154ms/step - loss: 3.0650e-05 - accuracy: 1.0000
# Epoch 61/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.9997e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 40s 159ms/step - loss: 3.0081e-05 - accuracy: 1.0000
# Epoch 62/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.9543e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 40s 161ms/step - loss: 2.9524e-05 - accuracy: 1.0000
# Epoch 63/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.9006e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 40s 161ms/step - loss: 2.8988e-05 - accuracy: 1.0000
# Epoch 64/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.8524e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 39s 157ms/step - loss: 2.8507e-05 - accuracy: 1.0000
# Epoch 65/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.8004e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 41s 163ms/step - loss: 2.7986e-05 - accuracy: 1.0000
# Epoch 66/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.7532e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 40s 159ms/step - loss: 2.7515e-05 - accuracy: 1.0000
# Epoch 67/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.7091e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 40s 158ms/step - loss: 2.7074e-05 - accuracy: 1.0000
# Epoch 68/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.6642e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 40s 158ms/step - loss: 2.6626e-05 - accuracy: 1.0000
# Epoch 69/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.6200e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 39s 157ms/step - loss: 2.6184e-05 - accuracy: 1.0000
# Epoch 70/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.5771e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 40s 160ms/step - loss: 2.5756e-05 - accuracy: 1.0000
# Epoch 71/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.5385e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 40s 159ms/step - loss: 2.5369e-05 - accuracy: 1.0000
# Epoch 72/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.4915e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 41s 165ms/step - loss: 2.4956e-05 - accuracy: 1.0000
# Epoch 73/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.4498e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 42s 167ms/step - loss: 2.4566e-05 - accuracy: 1.0000
# Epoch 74/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.4215e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 41s 164ms/step - loss: 2.4207e-05 - accuracy: 1.0000
# Epoch 75/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.3847e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 41s 162ms/step - loss: 2.3833e-05 - accuracy: 1.0000
# Epoch 76/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.3496e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 41s 165ms/step - loss: 2.3482e-05 - accuracy: 1.0000
# Epoch 77/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.3114e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 40s 160ms/step - loss: 2.3148e-05 - accuracy: 1.0000
# Epoch 78/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.2769e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 40s 160ms/step - loss: 2.2809e-05 - accuracy: 1.0000
# Epoch 79/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.2484e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 41s 163ms/step - loss: 2.2470e-05 - accuracy: 1.0000
# Epoch 80/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.2162e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 41s 163ms/step - loss: 2.2148e-05 - accuracy: 1.0000
# Epoch 81/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.1833e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 39s 157ms/step - loss: 2.1855e-05 - accuracy: 1.0000
# Epoch 82/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.1558e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 41s 163ms/step - loss: 2.1556e-05 - accuracy: 1.0000
# Epoch 83/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.1185e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 41s 162ms/step - loss: 2.1265e-05 - accuracy: 1.0000
# Epoch 84/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.0979e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 41s 163ms/step - loss: 2.0966e-05 - accuracy: 1.0000
# Epoch 85/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.0702e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 40s 159ms/step - loss: 2.0690e-05 - accuracy: 1.0000
# Epoch 86/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.0413e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 41s 163ms/step - loss: 2.0430e-05 - accuracy: 1.0000
# Epoch 87/100
# 250/251 [============================>.] - ETA: 0s - loss: 2.0174e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 42s 166ms/step - loss: 2.0162e-05 - accuracy: 1.0000
# Epoch 88/100
# 250/251 [============================>.] - ETA: 0s - loss: 1.9914e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 41s 164ms/step - loss: 1.9901e-05 - accuracy: 1.0000
# Epoch 89/100
# 250/251 [============================>.] - ETA: 0s - loss: 1.9541e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 41s 163ms/step - loss: 1.9648e-05 - accuracy: 1.0000
# Epoch 90/100
# 250/251 [============================>.] - ETA: 0s - loss: 1.9415e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 40s 161ms/step - loss: 1.9403e-05 - accuracy: 1.0000
# Epoch 91/100
# 250/251 [============================>.] - ETA: 0s - loss: 1.9171e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 42s 167ms/step - loss: 1.9160e-05 - accuracy: 1.0000
# Epoch 92/100
# 250/251 [============================>.] - ETA: 0s - loss: 1.8939e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 42s 169ms/step - loss: 1.8927e-05 - accuracy: 1.0000
# Epoch 93/100
# 250/251 [============================>.] - ETA: 0s - loss: 1.8693e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 42s 166ms/step - loss: 1.8714e-05 - accuracy: 1.0000
# Epoch 94/100
# 250/251 [============================>.] - ETA: 0s - loss: 1.8488e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 42s 167ms/step - loss: 1.8480e-05 - accuracy: 1.0000
# Epoch 95/100
# 250/251 [============================>.] - ETA: 0s - loss: 1.8271e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 40s 160ms/step - loss: 1.8259e-05 - accuracy: 1.0000
# Epoch 96/100
# 250/251 [============================>.] - ETA: 0s - loss: 1.8053e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 34s 134ms/step - loss: 1.8042e-05 - accuracy: 1.0000
# Epoch 97/100
# 250/251 [============================>.] - ETA: 0s - loss: 1.7856e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 32s 129ms/step - loss: 1.7844e-05 - accuracy: 1.0000
# Epoch 98/100
# 250/251 [============================>.] - ETA: 0s - loss: 1.7649e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 32s 126ms/step - loss: 1.7638e-05 - accuracy: 1.0000
# Epoch 99/100
# 250/251 [============================>.] - ETA: 0s - loss: 1.7447e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 32s 126ms/step - loss: 1.7441e-05 - accuracy: 1.0000
# Epoch 100/100
# 250/251 [============================>.] - ETA: 0s - loss: 1.7241e-05 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 251/251 [==============================] - 34s 137ms/step - loss: 1.7234e-05 - accuracy: 1.0000

# %%
ypreds = model.predict(xtest)
# Out:
# 64/64 [==============================] - 10s 114ms/step

# %%
ytest
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [1],
#        [1],
#        [1]])

# %%
plt.imshow(xtest[0])

# %%
ypreds
# Out:
# array([[2.8477031e-11],
#        [5.7627749e-06],
#        [8.1294284e-11],
#        ...,
#        [9.9979520e-01],
#        [1.0000000e+00],
#        [1.0000000e+00]], dtype=float32)

# %%
ypreds[ypreds > 0.5] = 1
ypreds[ypreds <= 0.5] = 0

# %%
ypreds
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [1.],
#        [1.],
#        [1.]], dtype=float32)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(ytest,ypreds)
# Out:
# 0.9817103311913
