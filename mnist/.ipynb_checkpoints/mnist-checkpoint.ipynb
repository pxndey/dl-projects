# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import precision_recall_curve,accuracy_score,f1_score,precision_score,recall_score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import losses

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
(xtrain,ytrain),(xtest,ytest) =tf.keras.datasets.mnist.load_data()

# %%
xtrain.shape
# Out:
# (60000, 28, 28)

# %%
xtest.shape
# Out:
# (10000, 28, 28)

# %%
xtrain = tf.pad(xtrain,[[0,0],[2,2],[2,2]])/255
xtest = tf.pad(xtest,[[0,0],[2,2],[2,2]])/255

# %%
xtrain = tf.expand_dims(xtrain, axis=3, name=None)
xtest = tf.expand_dims(xtest, axis=3, name=None)
xtrain.shape
# Out:
# TensorShape([60000, 32, 32, 1])

# %%
xval = xtrain[-2000:,:,:,:] 
yval = ytrain[-2000:] 
xtrain = xtrain[:-2000,:,:,:] 
ytrain = ytrain[:-2000]

# %%
model = Sequential()
model.add(layers.Conv2D(filters=6, kernel_size=(5,5), activation='tanh', input_shape=xtrain.shape[1:]))
model.add(layers.AveragePooling2D(2))
model.add(layers.Activation('sigmoid'))
model.add(layers.Conv2D(16, 5, activation='tanh'))
model.add(layers.AveragePooling2D(2))
model.add(layers.Activation('sigmoid'))
model.add(layers.Conv2D(120, 5, activation='tanh'))
model.add(layers.Flatten())
model.add(layers.Dense(84, activation='tanh'))
model.add(layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_6 (Conv2D)           (None, 28, 28, 6)         156
#
#  average_pooling2d_4 (Averag  (None, 14, 14, 6)        0
#  ePooling2D)
#
#  activation_4 (Activation)   (None, 14, 14, 6)         0
#
#  conv2d_7 (Conv2D)           (None, 10, 10, 16)        2416
#
#  average_pooling2d_5 (Averag  (None, 5, 5, 16)         0
#  ePooling2D)
#
#  activation_5 (Activation)   (None, 5, 5, 16)          0
#
#  conv2d_8 (Conv2D)           (None, 1, 1, 120)         48120
#
#  flatten_2 (Flatten)         (None, 120)               0
#
#  dense_4 (Dense)             (None, 84)                10164
#
#  dense_5 (Dense)             (None, 10)                850
#
# ...
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss=losses.sparse_categorical_crossentropy, metrics=['accuracy'])
history = model.fit(xtrain, ytrain, batch_size=64, epochs=40, validation_data=(xval, yval))
# Out:
# Epoch 1/40
# 907/907 [==============================] - 11s 11ms/step - loss: 1.2399 - accuracy: 0.5543 - val_loss: 0.2783 - val_accuracy: 0.9260
# Epoch 2/40
# 907/907 [==============================] - 11s 12ms/step - loss: 0.3450 - accuracy: 0.8912 - val_loss: 0.2143 - val_accuracy: 0.9345
# Epoch 3/40
# 907/907 [==============================] - 10s 11ms/step - loss: 0.2705 - accuracy: 0.9154 - val_loss: 0.1875 - val_accuracy: 0.9405
# Epoch 4/40
# 907/907 [==============================] - 10s 11ms/step - loss: 0.2252 - accuracy: 0.9285 - val_loss: 0.1381 - val_accuracy: 0.9620
# Epoch 5/40
# 907/907 [==============================] - 10s 11ms/step - loss: 0.1928 - accuracy: 0.9391 - val_loss: 0.1120 - val_accuracy: 0.9705
# Epoch 6/40
# 907/907 [==============================] - 10s 11ms/step - loss: 0.1739 - accuracy: 0.9450 - val_loss: 0.1196 - val_accuracy: 0.9665
# Epoch 7/40
# ...

# %%
fig, axs = plt.subplots(2, 1, figsize=(15,15))
axs[0].plot(history.history['loss']) 
axs[0].plot(history.history['val_loss']) 
axs[0].title.set_text('Training Loss vs Validation Loss') 
axs[0].legend(['Train', 'Val'])  
axs[1].plot(history.history['accuracy']) 
axs[1].plot(history.history['val_accuracy'])
axs[1].title.set_text('Training Accuracy vs Validation Accuracy') 
axs[1].legend(['Train', 'Val'])

# %%
model.evaluate(xtest, ytest)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0705 - accuracy: 0.9772
# [0.07049594819545746, 0.9772000312805176]

# %%
tensor = xtest[1010]
tensor
single_tensor = tensor[tf.newaxis, ...]
plt.imshow(tensor)

# %%
pred = model.predict(single_tensor)
pred
np.where(pred == pred.max())[1][0]
# Out:
# 1/1 [==============================] - 0s 67ms/step
# 4

# %%
def tf_printnum(tensor):
    tensor = tf.reshape(tensor,[32,32,1])
    tensor = tensor[tf.newaxis,...]
    pred = model.predict(tensor)
    print(np.where(pred == pred.max())[1][0])
    plt.imshow(tensor[0,:,:,0])

# %%
tf_printnum(xtest[2021])
# Out:
# 1/1 [==============================] - 0s 54ms/step
# 5

# %%
model

# %%
model.get_layer(index=0)

# %%
model.layers

# %%
model.layers[0].output
# Out:
# <KerasTensor: shape=(None, 28, 28, 6) dtype=float32 (created by layer 'conv2d_6')>

# %%
model.layers[1].output
# Out:
# <KerasTensor: shape=(None, 14, 14, 6) dtype=float32 (created by layer 'average_pooling2d_4')>

# %%
for i in range(len(model.layers)):
    print(model.layers[i].output)
    print("")
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28, 6), dtype=tf.float32, name=None), name='conv2d_6/Tanh:0', description="created by layer 'conv2d_6'")
#
# KerasTensor(type_spec=TensorSpec(shape=(None, 14, 14, 6), dtype=tf.float32, name=None), name='average_pooling2d_4/AvgPool:0', description="created by layer 'average_pooling2d_4'")
#
# KerasTensor(type_spec=TensorSpec(shape=(None, 14, 14, 6), dtype=tf.float32, name=None), name='activation_4/Sigmoid:0', description="created by layer 'activation_4'")
#
# KerasTensor(type_spec=TensorSpec(shape=(None, 10, 10, 16), dtype=tf.float32, name=None), name='conv2d_7/Tanh:0', description="created by layer 'conv2d_7'")
#
# KerasTensor(type_spec=TensorSpec(shape=(None, 5, 5, 16), dtype=tf.float32, name=None), name='average_pooling2d_5/AvgPool:0', description="created by layer 'average_pooling2d_5'")
#
# ...

# %%
tensor = xtest[0]
tensor
single_tensor = tensor[tf.newaxis, ...]
single_tensor.shape
# Out:
# TensorShape([1, 32, 32, 1])

# %%
plt.imshow(tensor)

# %%
from PIL import Image

# %%
i = Image.open('bric.jpeg')

# %%
i
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>

# %%
im = np.asarray(i)

# %%
tensor1 = tf.convert_to_tensor(im)

# %%
r,g,b = tf.split(tensor1,num_or_size_splits=3,axis=2)
r = r[tf.newaxis,...]
r.shape
# Out:
# TensorShape([1, 225, 225, 1])

# %%
r1 = tf.image.resize(r,[32,32,])

# %%
plt.imshow(r[0,:,:,0])

# %%
plt.imshow(r1[0,:,:,0])

# %%
from tensorflow.keras import backend as K
layerIndex = 0
func = K.function([model.get_layer(index=0).input], model.get_layer(index=layerIndex).output)
layerOutput = func([r1])  # input_data is a numpy array
plt.imshow(layerOutput[0,:,:,0])

# %%
from tensorflow.keras import backend as K
layerIndex = 1
func = K.function([model.get_layer(index=0).input], model.get_layer(index=layerIndex).output)
layerOutput = func([r1])  # input_data is a numpy array
plt.imshow(layerOutput[0,:,:,0])

# %%
from tensorflow.keras import backend as K
layerIndex = 2
func = K.function([model.get_layer(index=0).input], model.get_layer(index=layerIndex).output)
layerOutput = func([r1])  # input_data is a numpy array
plt.imshow(layerOutput[0,:,:,0])

# %%
from tensorflow.keras import backend as K
layerIndex = 3
func = K.function([model.get_layer(index=0).input], model.get_layer(index=layerIndex).output)
layerOutput = func([r1])  # input_data is a numpy array
plt.imshow(layerOutput[0,:,:,0])

# %%
from tensorflow.keras import backend as K
layerIndex = 4
func = K.function([model.get_layer(index=0).input], model.get_layer(index=layerIndex).output)
layerOutput = func([r1])  # input_data is a numpy array
plt.imshow(layerOutput[0,:,:,0])

# %%
from tensorflow.keras import backend as K
layerIndex = 5
func = K.function([model.get_layer(index=0).input], model.get_layer(index=layerIndex).output)
layerOutput = func([r1])  # input_data is a numpy array
plt.imshow(layerOutput[0,:,:,0])

# %%
from tensorflow.keras import backend as K
layerIndex = 6
func = K.function([model.get_layer(index=0).input], model.get_layer(index=layerIndex).output)
layerOutput = func([r1])  # input_data is a numpy array
plt.imshow(layerOutput[0,:,:,0])

# %%
from tensorflow.keras import backend as K
layerIndex = 7
func = K.function([model.get_layer(index=0).input], model.get_layer(index=layerIndex).output)
layerOutput = func([r1])  # input_data is a numpy array
plt.imshow(layerOutput)

# %%
from tensorflow.keras import backend as K
layerIndex = 8
func = K.function([model.get_layer(index=0).input], model.get_layer(index=layerIndex).output)
layerOutput = func([r1])  # input_data is a numpy array
plt.imshow(layerOutput)

# %%
from tensorflow.keras import backend as K
layerIndex = 9
func = K.function([model.get_layer(index=0).input], model.get_layer(index=layerIndex).output)
layerOutput = func([r1])  # input_data is a numpy array
plt.imshow(layerOutput)
